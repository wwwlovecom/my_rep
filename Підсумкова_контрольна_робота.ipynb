# %% [markdown]
# <a href="https://colab.research.google.com/github/wwwlovecom/my_rep/blob/main/%D0%9F%D1%96%D0%B4%D1%81%D1%83%D0%BC%D0%BA%D0%BE%D0%B2%D0%B0_%D0%BA%D0%BE%D0%BD%D1%82%D1%80%D0%BE%D0%BB%D1%8C%D0%BD%D0%B0_%D1%80%D0%BE%D0%B1%D0%BE%D1%82%D0%B0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Завдання 1

# %% [markdown]
# 1.   Прочитайте CSV файл

# %%
import pandas as pd

from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-0c5fff2c-1743-46ac-ba58-7813b3da90be" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0c5fff2c-1743-46ac-ba58-7813b3da90be">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('Global YouTube Statistics.csv', encoding='latin1')
df
# Out:
#      rank                    Youtuber  subscribers   video views  \
# 0       1                    T-Series    245000000  2.280000e+11
# 1       2              YouTube Movies    170000000  0.000000e+00
# 2       3                     MrBeast    166000000  2.836884e+10
# 3       4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4       5                   SET India    159000000  1.480000e+11
# ..    ...                         ...          ...           ...
# 990   991               Natan por Aï¿     12300000  9.029610e+09
# 991   992    Free Fire India Official     12300000  1.674410e+09
# 992   993                       Panda     12300000  2.214684e+09
# 993   994                 RobTopGames     12300000  3.741235e+08
# 994   995                Make Joke Of     12300000  2.129774e+09
#
#              category                       Title  uploads         Country  \
# 0               Music                    T-Series    20082           India
# ...

# %% [markdown]
# 2.   Виведіть перші п'ять рядків

# %%
df.head(5)
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %% [markdown]
# 3.   Виведіть розміри датасету, перевірте наявність пропусків, дублікатів

# %%
#Розмір
df.shape
# Out:
# (995, 28)

# %%
#Пропуски
df.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
#Дублікати
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# 4.   Якщо є пропуски, замінить тип даних на float і середнє значення за
# стовпцем
# 5.   Ще раз перевірте кількість пропусків

# %%
numeric_columns = df.select_dtypes(include='number').columns

numeric_columns_with_missing = [col for col in numeric_columns if df[col].isnull().any()]

print(numeric_columns_with_missing)
# Out:
# ['video_views_rank', 'country_rank', 'channel_type_rank', 'video_views_for_the_last_30_days', 'subscribers_for_last_30_days', 'created_year', 'created_date', 'Gross tertiary education enrollment (%)', 'Population', 'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude']

# %%
for col in numeric_columns_with_missing:
    mean_value = df[col].mean()
    df[col] = df[col].fillna(mean_value)

print("\nКількість пропусків після заміни:")
print(df[numeric_columns_with_missing].isnull().sum())
# Out:
# Кількість пропусків після заміни:
# video_views_rank                           0
# country_rank                               0
# channel_type_rank                          0
# video_views_for_the_last_30_days           0
# subscribers_for_last_30_days               0
# created_year                               0
# created_date                               0
# Gross tertiary education enrollment (%)    0
# Population                                 0
# Unemployment rate                          0
# Urban_population                           0
# Latitude                                   0
# Longitude                                  0
# dtype: int64

# %% [markdown]
# 6.   Перевірте, скільки унікальних країн представлено у колонці "Country"

# %%
unique_countries = df['Country'].nunique()
print("Кількість унікальних країн:", unique_countries)
print(df['Country'].unique())
# Out:
# Кількість унікальних країн: 49
# ['India' 'United States' nan 'Japan' 'Russia' 'South Korea'
#  'United Kingdom' 'Canada' 'Brazil' 'Argentina' 'Chile' 'Cuba'
#  'El Salvador' 'Pakistan' 'Philippines' 'Thailand' 'Colombia' 'Barbados'
#  'Mexico' 'United Arab Emirates' 'Spain' 'Saudi Arabia' 'Indonesia'
#  'Turkey' 'Venezuela' 'Kuwait' 'Jordan' 'Netherlands' 'Singapore'
#  'Australia' 'Italy' 'Germany' 'France' 'Sweden' 'Afghanistan' 'Ukraine'
#  'Latvia' 'Switzerland' 'Vietnam' 'Malaysia' 'China' 'Iraq' 'Egypt'
#  'Andorra' 'Ecuador' 'Morocco' 'Peru' 'Bangladesh' 'Finland' 'Samoa']

# %% [markdown]
# 7.   Побудуйте діаграму розподілу переглядів (використовуйте kind='hist')

# %%
import matplotlib.pyplot as plt

df['video views'].plot(kind='hist', bins=50, figsize=(10, 6), color='skyblue', edgecolor='black')

plt.title('Розподіл кількості переглядів відео на YouTube-каналах')
plt.xlabel('Кількість переглядів')
plt.ylabel('Кількість каналів')
plt.grid(axis='y', alpha=0.75)

plt.show()

# %% [markdown]
# 8.   Визначте максимальну, мінімальну, середню кількість переглядів
# (використовуйте методи max, min, mean)

# %%
max_views = df['video views'].max()
min_views = df['video views'].min()
mean_views = df['video views'].mean()

print(f"Максимальна кількість переглядів: {max_views}")
print(f"Мінімальна кількість переглядів: {min_views}")
print(f"Середня кількість переглядів: {mean_views}")
# Out:
# Максимальна кількість переглядів: 228000000000.0
# Мінімальна кількість переглядів: 0.0
# Середня кількість переглядів: 11039537052.03819

# %% [markdown]
# 9.   Знайдіть країну, де найбільше відео було завантажено на YouTube

# %%
uploads_by_country = df.groupby('Country')['uploads'].sum()
max_uploads_country = uploads_by_country.idxmax()
max_uploads_value = uploads_by_country.max()

print(f"Країна з найбільшим числом завантажених відео: {max_uploads_country} ({max_uploads_value} відео)")
# Out:
# Країна з найбільшим числом завантажених відео: India (3728212 відео)

# %% [markdown]
# 10.   Знайдіть відео (виведіть його назву) з найбільшою та найменшою
# кількістю завантажень uploads

# %%
max_uploads_idx = df['uploads'].idxmax()
max_uploads_title = df.loc[max_uploads_idx, 'Title']
max_uploads_value = df.loc[max_uploads_idx, 'uploads']

min_uploads_idx = df['uploads'].idxmin()
min_uploads_title = df.loc[min_uploads_idx, 'Title']
min_uploads_value = df.loc[min_uploads_idx, 'uploads']

print(f"Відео з найбільшою кількістю завантажень: '{max_uploads_title}' ({max_uploads_value} завантажень)")
print(f"Відео з найменшою кількістю завантажень: '{min_uploads_title}' ({min_uploads_value} завантажень)")
# Out:
# Відео з найбільшою кількістю завантажень: 'ABP NEWS' (301308 завантажень)
# Відео з найменшою кількістю завантажень: 'Music' (0 завантажень)

# %% [markdown]
# # Завдання 2

# %% [markdown]
# Зчитати архів Customer Shopping Trends Dataset
# Загрузіть цей файл

# %%
uploaded_2 = files.upload()
# Out:
#      <input type="file" id="files-7d97b178-bf7c-4aeb-934a-a0af0fcecdb4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d97b178-bf7c-4aeb-934a-a0af0fcecdb4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df_2 = pd.read_csv('shopping_trends.csv')
df_2
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# Перевірте розмір таблиці, наявність пропусків, тип
# стовпців
# Перейменуйте назви стовпців: Змініть прописні букви на строчні
# (маленькі) та пробіл на підкреслення

# %%
df_2.shape
# Out:
# (3900, 19)

# %%
df_2.isnull().sum()
# Out:
# Customer ID                 0
# Age                         0
# Gender                      0
# Item Purchased              0
# Category                    0
# Purchase Amount (USD)       0
# Location                    0
# Size                        0
# Color                       0
# Season                      0
# Review Rating               0
# Subscription Status         0
# Payment Method              0
# Shipping Type               0
# Discount Applied            0
# Promo Code Used             0
# Previous Purchases          0
# Preferred Payment Method    0
# Frequency of Purchases      0
# dtype: int64

# %%
df_2.dtypes
# Out:
# Customer ID                   int64
# Age                           int64
# Gender                       object
# Item Purchased               object
# Category                     object
# Purchase Amount (USD)         int64
# Location                     object
# Size                         object
# Color                        object
# Season                       object
# Review Rating               float64
# Subscription Status          object
# Payment Method               object
# Shipping Type                object
# Discount Applied             object
# Promo Code Used              object
# Previous Purchases            int64
# Preferred Payment Method     object
# Frequency of Purchases       object
# dtype: object

# %%
df_2.columns = df_2.columns.str.lower().str.replace(' ', '_')

# %%
df_2.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount_(usd)', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'payment_method',
#        'shipping_type', 'discount_applied', 'promo_code_used',
#        'previous_purchases', 'preferred_payment_method',
#        'frequency_of_purchases'],
#       dtype='object')

# %%
df_2
# Out:
#       customer_id  age  gender item_purchased     category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       purchase_amount_(usd)       location size      color  season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %% [markdown]
# 1.   Гістограма віку (age)
# Побудуйте гістограму віку клієнтів, використовуючи Seaborn

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(df_2['age'], bins=30, kde=False, color='skyblue')
plt.title('Гістограма віку клієнтів')
plt.xlabel('Вік')
plt.ylabel('Кількість клієнтів')
plt.show()

# %% [markdown]
# 2.   Порівняння розподілу покупок за статтею (item_purchased)

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=df_2, x='item_purchased', hue='gender')
plt.title('Порівняння розподілу покупок за статтю')
plt.xlabel('Товар')
plt.ylabel('Кількість покупок')
plt.xticks(rotation=45)
plt.legend(title='Стать')
plt.show()

# %% [markdown]
# 3.   Створіть стовпчасту діаграму або графік розподілу, щоб порівняти, які
# товари покупають клієнти найчастіше

# %%
plt.figure(figsize=(14,7))
sns.countplot(data=df_2, x='item_purchased', order=df_2['item_purchased'].value_counts().index)
plt.title('Найпопулярніші товари за кількістю покупок')
plt.xlabel('Товар')
plt.ylabel('Кількість покупок')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 4.   Залежність між віком та сумою покупок (purchase_amount)

# %%
plt.figure(figsize=(12,6))
sns.boxplot(data=df_2, x='age', y='purchase_amount_(usd)')
plt.title('Розподіл суми покупок за віком')
plt.xlabel('Вік')
plt.ylabel('Сума покупок (USD)')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 5.   Використовуйте scatter plot, щоб візуалізувати залежність між віком та
# сумою покупок

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df_2, x='age', y='purchase_amount_(usd)')
plt.title('Залежність суми покупок від віку')
plt.xlabel('Вік')
plt.ylabel('Сума покупок (USD)')
plt.show()

# %% [markdown]
# 6.   Графік розподілу оцінок товарів (review_rating)

# %%
plt.figure(figsize=(8,5))
sns.histplot(df_2['review_rating'], bins=20, kde=True)
plt.title('Розподіл оцінок товарів (Review Rating)')
plt.xlabel('Оцінка товару')
plt.ylabel('Кількість')
plt.show()

# %% [markdown]
# 7.   Побудуйте графік розподілу оцінок товарів для оцінки якості

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df_2['review_rating'])
plt.title('Розподіл оцінок товарів (Review Rating) — оцінка якості')
plt.xlabel('Оцінка товару')
plt.show()

# %% [markdown]
# 8.   Категоріальна діаграма для статі (gender)

# %%
plt.figure(figsize=(6,4))
sns.countplot(data=df_2, x='gender')
plt.title('Розподіл клієнтів за статтю')
plt.xlabel('Стать')
plt.ylabel('Кількість клієнтів')
plt.show()

# %% [markdown]
# 9.   Створіть категоріальну діаграму, щоб відобразити розподіл покупок за
# статтею

# %%
plt.figure(figsize=(6,4))
sns.barplot(data=df_2, x='gender', y='purchase_amount_(usd)', estimator=sum)
plt.title('Сума покупок за статтю')
plt.xlabel('Стать')
plt.ylabel('Сума покупок (USD)')
plt.show()

# %% [markdown]
# 10.   Залежність між рейтингом і сумою покупок (review_rating і
# purchase_amount)

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df_2, x='review_rating', y='purchase_amount_(usd)')
plt.title('Розподіл суми покупок за рейтингом товару')
plt.xlabel('Рейтинг товару')
plt.ylabel('Сума покупок (USD)')
plt.show()

# %% [markdown]
# # Завдання 3

# %% [markdown]
# 1.   Створіть горизонтальну діаграму з мітками на основі даних про
# врожайність пшениці (data.wheat()) за допомогою бібліотеки Altair.
# Задайте вісь x для врожайності пшениці, вісь y для років, а текстові
# мітки відображайте значення врожайності пшениці на відповідних
# роках.

# %%
import altair as alt
from vega_datasets import data

wheat_data = data.wheat()

bars = alt.Chart(wheat_data).mark_bar().encode(
    x=alt.X('wheat:Q', title='Врожайність пшениці'),
    y=alt.Y('year:O', title='Рік', sort='-x')
).properties(
    title='Врожайність пшениці за роками'
)

labels = alt.Chart(wheat_data).mark_text(
    align='left',
    baseline='middle',
    dx=3
).encode(
    x='wheat:Q',
    y=alt.Y('year:O', sort='-x'),
    text='wheat:Q'
)


final_chart = bars + labels
final_chart
# Out:
# alt.LayerChart(...)

# %% [markdown]
# 2.   Створіть багатошарову діаграму на основі даних про виробництво
# електроенергії в штаті Айова (data.iowa_electricity()) за допомогою
# бібліотеки Altair . Вісь x представляє роки, вісь y відображає чисте
# виробництво електроенергії (net_generation), а кожен шар діаграми
# позначає різні джерела енергії (source). Встановіть прозорість (opacity)
# для стовпців на рівні 0.7.

# %%
electricity_data = data.iowa_electricity()

chart = alt.Chart(electricity_data).mark_bar(opacity=0.7).encode(
    x=alt.X('year:T', title='Рік'),
    y=alt.Y('net_generation:Q', title='Чисте виробництво електроенергії'),
    color=alt.Color('source:N', title='Джерело енергії'),
    tooltip=['year:T', 'source:N', 'net_generation:Q']
).properties(
    title='Виробництво електроенергії в Айові за джерелами'
)

chart
# Out:
# alt.Chart(...)

# %% [markdown]
# 3.   Створіть графік за допомогою бібліотеки Plotly (scatter plot) для даних
# ірисів (iris dataset), де:
# Вісь X (x-axis) відповідає ширині чашелистика (sepal width).
# Вісь Y (y-axis) відповідає довжині чашелистика (sepal length).
# Кожен пункт на графіку має розмір, який залежить від довжини
# пелюстки (petal length).
# Кожен пункт на графіку має різний колір в залежності від виду
# (species).
# При наведенні на пункт повинні відображатися додаткові дані, такі як
# ширина пелюстки (petal width)

# %%
import plotly.express as px

iris = data.iris()

fig = px.scatter(
    iris,
    x='sepalWidth',
    y='sepalLength',
    size='petalLength',
    color='species',
    hover_data=['petalWidth'],
    labels={
        'sepalWidth': 'Ширина чашелистика',
        'sepalLength': 'Довжина чашелистика',
        'petalLength': 'Довжина пелюстки',
        'petalWidth': 'Ширина пелюстки',
        'species': 'Вид'
    },
    title='Графік ірисів: співвідношення параметрів квітки'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
